# %% [markdown]
# <a href="https://colab.research.google.com/github/MeetSolanki100/SynapseTasks/blob/main/Task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/netflix_titles.csv")

# %%
df.head(10)
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
# ...

# %%
df.dropna(inplace = True)
df.reset_index(inplace = True)
df
# Out:
#       index show_id     type                          title  \
# 0         7      s8    Movie                        Sankofa
# 1         8      s9  TV Show  The Great British Baking Show
# 2         9     s10    Movie                   The Starling
# 3        12     s13    Movie                   Je Suis Karl
# 4        24     s25    Movie                          Jeans
# ...     ...     ...      ...                            ...
# 5327   8801   s8802    Movie                        Zinzana
# 5328   8802   s8803    Movie                         Zodiac
# 5329   8804   s8805    Movie                     Zombieland
# 5330   8805   s8806    Movie                           Zoom
# 5331   8806   s8807    Movie                         Zubaan
#
#                  director                                               cast  \
# 0            Haile Gerima  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 1         Andy Devonshire  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# ...

# %%
newdf  = len(df[(df['release_year']==2021)&(df['type']=="Movie")])

# %%
newdf
# Out:
# 146

# %%
avengers_df = df[df['title'].str.contains('Avengers')]
avengers_df
# Out:
#       index show_id   type                                            title  \
# 2934   5340   s5341  Movie  LEGO Marvel Super Heroes: Avengers Reassembled!
# 3500   6200   s6201  Movie                           Avengers: Infinity War
#
#                       director  \
# 2934             Rob Silvestri
# 3500  Anthony Russo, Joe Russo
#
#                                                    cast        country  \
# 2934  Laura Bailey, Troy Baker, Eric Bauza, Ben Disk...  United States
# 3500  Robert Downey Jr., Josh Brolin, Mark Ruffalo, ...  United States
#
#              date_added  release_year rating duration  \
# 2934     August 6, 2017          2015  TV-Y7   22 min
# 3500  December 25, 2018          2018  PG-13  150 min
#
#                                  listed_in  \
# 2934              Children & Family Movies
# 3500  Action & Adventure, Sci-Fi & Fantasy
#
#                                             description
# 2934  When Ultron seizes control of Iron Man's armor...
# ...

# %%
smol_df= df['country'].value_counts()
smol_df
# Out:
# United States                                   1846
# India                                            875
# United Kingdom                                   183
# Canada                                           107
# Spain                                             91
#                                                 ...
# Uruguay, Guatemala                                 1
# Romania, Bulgaria, Hungary                         1
# Philippines, United States                         1
# India, United Kingdom, Canada, United States       1
# United Arab Emirates, Jordan                       1
# Name: country, Length: 604, dtype: int64

# %%
top = smol_df.head(5)
top
# Out:
# United States     1846
# India              875
# United Kingdom     183
# Canada             107
# Spain               91
# Name: country, dtype: int64

# %%
result_df = df[(df['country'].isin(top.index))]

result_df.reset_index(inplace = True)
result_df
# Out:
#       level_0  index show_id     type                          title  \
# 0           1      8      s9  TV Show  The Great British Baking Show
# 1           2      9     s10    Movie                   The Starling
# 2           4     24     s25    Movie                          Jeans
# 3           5     27     s28    Movie                      Grown Ups
# 4           6     28     s29    Movie                     Dark Skies
# ...       ...    ...     ...      ...                            ...
# 3097     5326   8799   s8800    Movie                          Zenda
# 3098     5328   8802   s8803    Movie                         Zodiac
# 3099     5329   8804   s8805    Movie                     Zombieland
# 3100     5330   8805   s8806    Movie                           Zoom
# 3101     5331   8806   s8807    Movie                         Zubaan
#
#              director                                               cast  \
# ...

# %%
plt.pie(smol_df.values, labels=smol_df.index, autopct='%1.1f%%')
plt.title('No.of movies per Country')
plt.show()
